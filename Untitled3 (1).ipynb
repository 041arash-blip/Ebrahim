# %%
# ۱. آپدیت سیستم و نصب ابزارهای مورد نیاز اندروید و جاوا
# !apt-get update
# !apt-get install -y openjdk-17-jdk-headless python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip install --upgrade pip

# ۲. نصب Buildozer (ابزار اصلی برای ساخت APK)
# !pip install buildozer

# ۳. نصب Cython (برای تبدیل کد پایتون به زبان C که اندروید می‌فهمد)
# !pip install cython==0.29.33

# ۴. ایجاد یک پوشه برای پروژه
# !mkdir smart_risk_project
# %cd smart_risk_project

print("\n✅ نصب با موفقیت انجام شد! حالا منتظر باش تا تمام شود...")
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [105 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,158 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# ...
